# %% [markdown]
# # Derek Sandefur
# ## Week 15 - 4/23/2024
# ### Python Data Visualization - Making informative visualizations (using plots).

# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# These are plotting modules
import matplotlib as mpl
import matplotlib.pyplot as plt

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
d = randn(20)
d
# Out:
# array([ 0.42335185, -0.34854456, -0.43349282,  0.96728572,  0.6536434 ,
#        -0.87055313,  0.394247  ,  0.05022542,  2.51961256,  1.15517489,
#         0.11206772,  0.20181336,  0.23738792,  1.11508276,  0.80229576,
#        -0.37161395,  0.32641784,  0.67847997, -0.25756001,  1.46304315])

# %%
s = pd.Series(d)
s
# Out:
# 0     0.423352
# 1    -0.348545
# 2    -0.433493
# 3     0.967286
# 4     0.653643
# 5    -0.870553
# 6     0.394247
# 7     0.050225
# 8     2.519613
# 9     1.155175
# 10    0.112068
# 11    0.201813
# 12    0.237388
# 13    1.115083
# 14    0.802296
# 15   -0.371614
# 16    0.326418
# 17    0.678480
# 18   -0.257560
# 19    1.463043
# dtype: float64

# %%
plt.plot(s)

# %%
df = pd.DataFrame(d)
df
# Out:
#            0
# 0   0.423352
# 1  -0.348545
# 2  -0.433493
# 3   0.967286
# 4   0.653643
# 5  -0.870553
# 6   0.394247
# 7   0.050225
# 8   2.519613
# 9   1.155175
# 10  0.112068
# 11  0.201813
# 12  0.237388
# 13  1.115083
# 14  0.802296
# 15 -0.371614
# 16  0.326418
# 17  0.678480
# 18 -0.257560
# 19  1.463043

# %%
dataset1 = randn(100)
dataset1
# Out:
# array([-1.31585186e+00, -2.46627767e-01, -1.53373757e-01,  1.61378474e+00,
#         1.60697246e+00, -7.07014922e-01,  6.85790788e-01, -1.00382198e-01,
#        -1.82241938e+00, -4.82841846e-01,  1.43702383e-01,  1.10304451e+00,
#         3.05856196e-01, -7.63236347e-01, -2.53835185e-02, -5.32082766e-01,
#        -2.00832858e-01,  1.09899553e-01, -1.42034653e-01,  1.79063289e-01,
#         1.28650088e+00, -1.89258925e-01, -1.10829453e+00,  7.36885876e-01,
#        -8.04746019e-01,  1.55473390e+00, -1.24628486e+00, -7.54825889e-01,
#         2.10281985e+00,  7.23005727e-01,  1.42232739e+00,  3.79942093e-01,
#         8.83258939e-01,  6.45750171e-01, -1.36985991e+00,  7.75727378e-01,
#        -2.09330758e+00, -1.54302607e+00, -1.65599772e+00, -1.49344218e+00,
#         1.03840613e+00, -1.90516056e+00, -8.54918528e-01, -1.62924242e+00,
#        -6.15400285e-01, -1.36378016e+00,  1.44114601e+00,  4.93660277e-01,
#         9.42305131e-01, -1.59309797e-01, -8.41109395e-01, -1.22768559e+00,
#         1.60311747e+00,  8.67829921e-01,  1.03744442e+00, -1.35672176e+00,
#        -1.34871449e+00,  2.23128163e-01, -3.91438171e-01, -1.02888817e+00,
#         2.30741416e+00,  5.98767360e-01,  4.44432397e-01,  6.24054735e-01,
#        -1.55830406e+00,  9.42779075e-01,  1.21773954e-01, -7.18795145e-01,
#        -6.56495199e-01, -1.75009421e+00, -2.17877598e-01,  1.31528141e+00,
#        -1.14731125e+00, -1.26198232e+00,  8.03580987e-01,  8.13343832e-01,
#        -7.58711198e-01, -5.44355759e-01,  1.00819206e+00,  2.69079766e-01,
#         6.77641829e-01,  5.38548425e-01,  1.23421522e+00,  1.58452080e+00,
#        -1.35749613e+00, -8.07410968e-01, -1.08118132e+00,  1.08371166e+00,
#        -1.88826741e-01,  1.60087005e+00,  7.13492272e-01,  3.03835523e-01,
#         6.64133116e-01, -9.04454757e-03,  7.55929059e-01, -2.30177015e-01,
#         2.28222819e-02, -1.09314667e-04,  4.65591247e-01, -8.58588323e-01])

# %%
plt.hist(pd.Series(dataset1))
# Out:
# (array([ 5., 13.,  9., 11., 14., 13., 17.,  9.,  7.,  2.]),
#  array([-2.09330758, -1.65323541, -1.21316323, -0.77309106, -0.33301889,
#          0.10705329,  0.54712546,  0.98719763,  1.42726981,  1.86734198,
#          2.30741416]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2,color='red')
# Out:
# (array([ 2., 10.,  4., 14., 14.,  9., 12.,  6.,  6.,  3.]),
#  array([-2.26409302, -1.8561477 , -1.44820239, -1.04025707, -0.63231175,
#         -0.22436643,  0.18357888,  0.5915242 ,  0.99946952,  1.40741484,
#          1.81536015]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, color='indianred', alpha=0.5,bins=20)
plt.hist(dataset2, alpha=0.8,bins=20)
# Out:
# (array([ 2.,  0.,  3.,  7.,  2.,  2.,  3., 11.,  7.,  7.,  6.,  3.,  7.,
#          5.,  2.,  4.,  3.,  3.,  1.,  2.]),
#  array([-2.26409302, -2.06012036, -1.8561477 , -1.65217504, -1.44820239,
#         -1.24422973, -1.04025707, -0.83628441, -0.63231175, -0.42833909,
#         -0.22436643, -0.02039377,  0.18357888,  0.38755154,  0.5915242 ,
#          0.79549686,  0.99946952,  1.20344218,  1.40741484,  1.6113875 ,
#          1.81536015]),
#  <a list of 20 Patch objects>)

# %%
# Figures and Subplots
fig = plt.figure()

# %%
fig = plt.figure(figsize = (2,4), dpi=100)

# %%
#add_subplot
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1) #add_sublot(nrows, ncols, index, **kwargs)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
ax4.plot(dataset1)

# %%
fig

# %%
ax2.plot(dataset2)

# %%
fig

# %%
ax1.hist(dataset2)
# Out:
# (array([ 2., 10.,  4., 14., 14.,  9., 12.,  6.,  6.,  3.]),
#  array([-2.26409302, -1.8561477 , -1.44820239, -1.04025707, -0.63231175,
#         -0.22436643,  0.18357888,  0.5915242 ,  0.99946952,  1.40741484,
#          1.81536015]),
#  <a list of 10 Patch objects>)

# %%
fig

# %%
ax3.plot([2.5,10,30,-5,8,3,6])

# %%
fig

# %%
ax4.plot([10,3,5,-9,11,-3,-9,8,18,20], 'k--')

# %%
fig

# %%
dataset = randn(50).cumsum()
dataset
# Out:
# array([ 6.86181331e-01,  7.73898619e-01,  1.49906315e+00,  2.59664867e-01,
#         5.26671879e-01,  4.45709718e-01,  6.08850059e-01, -3.19187880e-01,
#         5.86053447e-01, -1.02382491e+00,  8.83128798e-01, -2.09470741e-01,
#        -9.35859118e-03, -5.95181368e-01, -7.07427323e-01, -2.29269511e+00,
#        -3.86074982e+00, -4.02762822e+00, -3.17869062e+00, -2.93745763e+00,
#        -2.49761893e+00, -3.44031329e+00, -2.06593297e+00, -2.26218996e+00,
#        -2.29151450e+00, -1.73436711e+00, -1.99234267e+00, -2.69087620e+00,
#        -2.53841590e+00, -1.41324656e+00, -3.33979394e+00, -2.81243546e+00,
#        -3.37830495e+00, -4.43026935e+00, -5.17908081e+00, -7.47348229e+00,
#        -6.61374908e+00, -5.69952068e+00, -8.24214877e+00, -8.45800106e+00,
#        -7.27820054e+00, -7.46315322e+00, -6.81046524e+00, -6.86913118e+00,
#        -7.77043099e+00, -9.04831788e+00, -6.63991390e+00, -7.93812822e+00,
#        -9.12158796e+00, -9.78452406e+00])

# %%
fig1= plt.figure()
ax1 = fig1.add_subplot(2,1,1)
ax2 = fig1.add_subplot(2,1,2)

# %%
ax1.plot(dataset, 'k.')
ax2.plot(dataset, 'k--')

# %%
fig1

# %%
ax1.hist(randn(100), bins=20, color='k', alpha=0.5)
ax2.scatter(np.arange(30), randn(30).cumsum()) #scatter(x,y)
fig1

# %%
fig3= plt.figure()
ax1 = fig3.add_subplot(2,2,1)
ax2 = fig3.add_subplot(2,2,2)

ax1.hist(randn(100), bins=20, color='k', alpha=0.5)
ax2.scatter(np.arange(30), randn(30).cumsum()) #scatter(x,y)

# %%
# Colors, Markers, and Line Styles
plt.plot(randn(50).cumsum(), 'ko--')

# %%
plt.plot(4 * randn(50).cumsum(), 'ko--')

# %%
plt.plot(4 * randn(50).cumsum(), color='k', linestyle='dotted', marker='o') # 'dashed', 'solid'

# %%
df = pd.DataFrame(randn(30).cumsum())
df
# Out:
#             0
# 0   -0.228980
# 1    0.859004
# 2    2.177510
# 3    2.797942
# 4    2.058142
# 5    1.436591
# 6    2.843501
# 7    2.578270
# 8    2.494216
# 9    2.839370
# 10   5.607647
# 11   5.429688
# 12   7.151946
# 13   6.961575
# 14   7.636030
# 15   7.447450
# 16   9.783257
# 17  10.369197
# 18   9.034942
# 19   9.996925
# 20  12.323939
# 21  11.471400
# 22  11.959083
# 23  11.922032
# 24  11.708818
# 25  11.263896
# 26  11.042524
# 27  10.748857
# 28  11.138889
# 29  10.124635

# %%
plt.plot( df, drawstyle='steps-post')

# %%
plt.plot(df, 'k--')
plt.plot(df, 'k-', drawstyle='steps-post')

# %%
#using labels
plt.plot(df, 'k--', label='Dashed-Line')
plt.plot(df, 'k-', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best') # axes.locs = ["upper left", "lower left", "center right"]

# %%
d = {'col1': randn(20), 'col2':randn(20).cumsum()}
d
# Out:
# {'col1': array([-1.85431535, -1.18862847,  0.74895528, -0.41274209,  0.35359066,
#         -0.64672688, -0.12537855,  0.29440952,  0.28215451,  0.44882452,
#         -0.25089053, -0.20905611,  0.61156232,  1.01988507, -0.13077614,
#         -0.37658628,  0.25053922, -1.22670713, -0.15809641,  0.57420198]),
#  'col2': array([ 0.81011557,  0.21859157,  0.56538635,  0.08939228,  1.45608745,
#         -0.32842056, -0.31096942,  1.06401519,  2.11973878,  0.70565069,
#          1.59189726,  0.42811089,  1.46781336,  2.22781577,  1.93109796,
#          0.96117249,  2.07040752,  1.947325  ,  4.56985445,  3.8758042 ])}

# %%
df = pd.DataFrame(d)
df
# Out:
#         col1      col2
# 0  -1.854315  0.810116
# 1  -1.188628  0.218592
# 2   0.748955  0.565386
# 3  -0.412742  0.089392
# 4   0.353591  1.456087
# 5  -0.646727 -0.328421
# 6  -0.125379 -0.310969
# 7   0.294410  1.064015
# 8   0.282155  2.119739
# 9   0.448825  0.705651
# 10 -0.250891  1.591897
# 11 -0.209056  0.428111
# 12  0.611562  1.467813
# 13  1.019885  2.227816
# 14 -0.130776  1.931098
# 15 -0.376586  0.961172
# 16  0.250539  2.070408
# 17 -1.226707  1.947325
# 18 -0.158096  4.569854
# 19  0.574202  3.875804

# %%
plt.plot(df['col1'], 'k.', label='col1')
plt.plot(df['col2'], 'ko--', label='col2')
plt.legend(loc='best')

# %%
#DataFrame plotting
df['col1'].plot()

# %%
df['col2'].plot.bar()

# %%
#Ticks, Labels, and Legends
fig = plt.figure()
ax = fig.add_subplot(111)

# %%
ax.plot(randn(1000).cumsum())

# %%
fig

# %%
ax.set_xticks([0,250,500,750,1000])
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')

ax.set_title('My First Matplotlip Plot with Ticks')
ax.set_xlabel('Stages')
ax.set_ylabel('Values')

fig

# %%
#Use dictionary for title, xlabel, and ylabel
props ={'title': 'My First Matplotlip Plot with Ticks',
       'xlabel': 'Stages',
       'ylabel': 'Values'}

ax.set(**props)
fig

# %%
#saving a figure in an image file
fig.savefig("fig1.png")
